# %%
import pandas as pd
# !pip3 install lxml
# !pip3 install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 19.0 MB/s
# ...

# %%
df = pd.read_excel('Classeur3.xlsx')
df['errors'] = df['errors'].fillna(method='backfill')

# %%
df
# Out:
#                    code                                              value  \
# 0             categorie                              barbecue_charbon_bois
# 1               couleur                                            noir-01
# 2     couvercle_cuisson                                                oui
# 3           description  <p>Profitez d'un barbecue à charbon de bois ty...
# 4                   ean                                      3584170443289
# ...                 ...                                                ...
# 9075             marque                                         beaurivage
# 9076           shop_sku                                      ZGPBAN2100002
# 9077    utilisation_bbq                                          sur_pieds
# 9078                NaN                                                NaN
# 9079                NaN                                                NaN
#
# ...

# %%
df.to_csv('df.csv', sep='\t', encoding='utf-8')
